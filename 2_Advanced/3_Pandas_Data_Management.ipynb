# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# DataFrame Copy
df_original = df.copy()

# %%
#To generate 10 samples of our data frame we can use:

df.sample(10)
# Out:
#               job_title_short  \
# 671166           Data Analyst
# 166795   Senior Data Engineer
# 528723         Data Scientist
# 684480  Senior Data Scientist
# 525736       Business Analyst
# 289163          Data Engineer
# 499411           Data Analyst
# 686132          Data Engineer
# 658349         Data Scientist
# 15423          Data Scientist
#
#                                                 job_title  \
# 671166                                       Data Analyst
# 166795  Senior Data Engineer | Leading International T...
# 528723    Data Scientist / Computational Protein Engineer
# 684480                      Senior Data Scientist (f/m/x)
# 525736   Senior Business Analyst, Artificial Intelligence
# 289163                  Data Engineer  - Contract to Hire
# 499411                Operations Data Analyst - Full-time
# 686132                                      Data Engineer
# 658349                                     Data Scientist
# 15423                                      Data Scientist
#
#                                     job_location        job_via  \
# 671166                            Poznań, Poland  via Adzuna.pl
# 166795  Milan, Metropolitan City of Milan, Italy   via Linkedin
# 528723                                     Spain   via LinkedIn
# 684480                            Aalen, Germany  via Stepstone
# 525736                                  Anywhere   via LinkedIn
# 289163                                  Anywhere     via Upwork
# 499411                                  Anywhere   via Snagajob
# 686132                                  Anywhere   via LinkedIn
# 658349                                  Anywhere   via LinkedIn
# 15423                              Palo Alto, CA     via Adzuna
#
#        job_schedule_type  job_work_from_home            search_location  \
# 671166         Full-time               False                     Poland
# 166795         Full-time               False                      Italy
# 528723         Full-time               False                      Spain
# 684480         Full-time               False                    Germany
# 525736         Full-time                True                  Australia
# 289163         Full-time                True                      Sudan
# 499411         Full-time                True  California, United States
# 686132         Full-time                True             United Kingdom
# 658349         Full-time                True                    Belgium
# 15423          Full-time               False  California, United States
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 671166 2023-11-23 10:21:09                   True                 False
# 166795 2023-06-30 15:17:12                   True                 False
# 528723 2023-06-12 11:32:18                  False                 False
# 684480 2023-12-22 10:18:19                  False                 False
# 525736 2023-09-06 11:39:01                  False                 False
# 289163 2023-08-12 17:32:41                  False                  True
# 499411 2023-02-06 11:01:15                  False                  True
# 686132 2023-07-11 10:23:09                  False                 False
# 658349 2023-09-19 10:23:10                  False                 False
# 15423  2023-02-13 13:04:41                  False                 False
#
#            job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 671166          Poland        None              NaN              NaN
# 166795           Italy        None              NaN              NaN
# 528723           Spain        None              NaN              NaN
# 684480         Germany        None              NaN              NaN
# 525736       Australia        None              NaN              NaN
# 289163           Sudan        None              NaN              NaN
# 499411   United States        None              NaN              NaN
# 686132  United Kingdom        None              NaN              NaN
# 658349         Belgium        None              NaN              NaN
# 15423    United States        None              NaN              NaN
#
#                                 company_name  \
# 671166                     LeasingTeam Group
# 166795                                  Hays
# 528723  Universitat Pompeu Fabra - Barcelona
# 684480                                 ZEISS
# 525736                               Glamezy
# 289163                                Upwork
# 499411        KARL STORZ Endoscopy - America
# 686132                          BIPROCSI LTD
# 658349     Engineering International Belgium
# 15423                               Sunshine
#
#                                                job_skills  \
# 671166                                               None
# 166795                                   ['sql', 'azure']
# 528723                                               None
# 684480  ['python', 'r', 'sql', 'azure', 'aws', 'excel'...
# 525736  ['python', 'java', 'sql', 'r', 'sas', 'sas', '...
# 289163                       ['python', 'sql', 'tableau']
# 499411        ['sql', 'python', 'r', 'tableau', 'looker']
# 686132   ['python', 'html', 'gcp', 'snowflake', 'looker']
# 658349                            ['sql', 'azure', 'dax']
# 15423          ['r', 'python', 'matlab', 'sql', 'pandas']
#
#                                           job_type_skills
# 671166                                               None
# 166795       {'cloud': ['azure'], 'programming': ['sql']}
# 528723                                               None
# 684480  {'analyst_tools': ['excel', 'tableau', 'power ...
# 525736  {'analyst_tools': ['sas', 'power bi', 'tableau...
# 289163  {'analyst_tools': ['tableau'], 'programming': ...
# 499411  {'analyst_tools': ['tableau', 'looker'], 'prog...
# 686132  {'analyst_tools': ['looker'], 'cloud': ['gcp',...
# 658349  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 15423   {'libraries': ['pandas'], 'programming': ['r',...

# %%
#If you want to have the same results returned from a sample we can use:

df.sample(10, random_state=42)
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
# 541983           Data Analyst
# 416896         Data Scientist
# 780907          Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
# 541983                   Data Analyst, Cloud Systems Jobs
# 416896             Alternant Actuariat & Data Science H/F
# 780907              Data Engineer with Fivetran,Qlik Must
#
#                      job_location                 job_via job_schedule_type  \
# 502901                St Paul, MN               via BeBee         Full-time
# 406337                 London, UK            via LinkedIn         Full-time
# 659951    Newcastle upon Tyne, UK              via Indeed         Full-time
# 541593                      Malta         via Trabajo.org         Full-time
# 425158     Amsterdam, Netherlands          via NBC4i Jobs         Full-time
# 183426                  Singapore  via Singapore | JobsDB         Full-time
# 287790                  Tampa, FL            via LinkedIn         Full-time
# 541983              Chantilly, VA      via Clearance Jobs         Full-time
# 416896                     France            via LinkedIn         Full-time
# 780907  Mexico City, CDMX, Mexico        via BeBee México         Full-time
#
#         job_work_from_home         search_location     job_posted_date  \
# 502901               False  Florida, United States 2023-12-17 11:09:06
# 406337               False          United Kingdom 2023-10-06 16:09:56
# 659951               False          United Kingdom 2023-09-06 10:11:25
# 541593               False                   Malta 2023-02-14 21:14:18
# 425158               False             Netherlands 2023-06-19 16:34:30
# 183426               False               Singapore 2023-11-09 16:07:57
# 287790               False  Florida, United States 2023-07-14 17:02:23
# 541983               False                 Georgia 2023-06-15 19:44:34
# 416896               False                  France 2023-09-22 16:47:24
# 780907               False                  Mexico 2023-01-16 06:19:09
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 502901                  False                 False   United States
# 406337                  False                 False  United Kingdom
# 659951                   True                 False  United Kingdom
# 541593                   True                 False           Malta
# 425158                   True                 False     Netherlands
# 183426                  False                 False       Singapore
# 287790                   True                 False   United States
# 541983                  False                 False   United States
# 416896                  False                 False          France
# 780907                  False                 False          Mexico
#
#        salary_rate  salary_year_avg  salary_hour_avg            company_name  \
# 502901        None              NaN              NaN           ManpowerGroup
# 406337        None              NaN              NaN                 Harnham
# 659951        None              NaN              NaN             Morgan King
# 541593        None              NaN              NaN                 Konnekt
# 425158        None              NaN              NaN  Independent Recruiters
# 183426        None              NaN              NaN    FLEXOSENSE PTE. LTD.
# 287790        None              NaN              NaN      Iris Software Inc.
# 541983        None              NaN              NaN                    SAIC
# 416896        None              NaN              NaN             KPMG France
# 780907        None              NaN              NaN        CORUS Consulting
#
#                                                job_skills  \
# 502901                            ['sql', 'azure', 'git']
# 406337  ['sql', 'python', 'bigquery', 'snowflake', 'lo...
# 659951                                               None
# 541593                                           ['jira']
# 425158                                         ['python']
# 183426  ['r', 'python', 'java', 'sql', 'sql server', '...
# 287790                         ['sql', 'hadoop', 'excel']
# 541983  ['sql', 'r', 'matlab', 'python', 'oracle', 'aw...
# 416896                                               None
# 780907  ['oracle', 'snowflake', 'aws', 'azure', 'alter...
#
#                                           job_type_skills
# 502901  {'cloud': ['azure'], 'other': ['git'], 'progra...
# 406337  {'analyst_tools': ['looker'], 'cloud': ['bigqu...
# 659951                                               None
# 541593                                {'async': ['jira']}
# 425158                        {'programming': ['python']}
# 183426  {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 287790  {'analyst_tools': ['excel'], 'libraries': ['ha...
# 541983  {'analyst_tools': ['power bi', 'tableau', 'qli...
# 416896                                               None
# 780907  {'analyst_tools': ['alteryx'], 'cloud': ['orac...

# %% [markdown]
# **Copy**
#
# It makes a copy of this object's indices and data.

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

# %%
df_altered = df_original

# %%
median_salary = df_altered['salary_year_avg'].median()

median_salary
# Out:
# 115000.0

# %%
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

df_altered.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

# %%
df_altered = df_original.copy()

# %%
print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('Are the two dataframes the same? ', id(df_original) == id(df_altered))
# Out:
# ID of df_original:                5596646480
# ID of df_altered:                 5851424080
# Are the two dataframes the same?  False

# %%
#Here we are altering the contents of the df_altered data frame and not the original data frame

median_salary = df_altered['salary_year_avg'].median()

df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

df_altered.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
#This is to confirm that the original data frame is not altered

df_original.loc[:5, 'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('Are the two dataframes the same? ', id(df_original) == id(df_altered))
# Out:
# ID of df_original:                5596646480
# ID of df_altered:                 5851424080
# Are the two dataframes the same?  False
