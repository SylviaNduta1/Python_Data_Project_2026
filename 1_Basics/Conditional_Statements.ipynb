# %% [markdown]
# ![Screenshot 2026-02-07 at 02.31.09.png](data:image/png;base64,...)

# %%
if True:
  print("What's up Sly?")
# Out:
# What's up Sly?

# %%
# Applicant skill
applicant_skill = 'SQL'

# Skill required for job posting
job_skill = 'SQL'

# Initialize result: assigning a default value to indicate the search status for the skill.
#result = 'No Skills Match'

# %%
if job_skill == applicant_skill:
  print('Skills Match')
# Out:
# Skills Match

# %%
job_skill = 'SQL'
applicant_skill = 'Python'
years_experience = 6


if job_skill == applicant_skill:
  print('Skills Match')
elif years_experience >= 5:
  print('Enough Experience; No SQL')
# Out:
# Enough Experience; No SQL

# %%
job_skill = 'SQL'
applicant_skill = 'Python'
years_experience = 3


if job_skill == applicant_skill:
  print('Skills Match')
elif years_experience >= 5:
  print('Enough Experience; No SQL')
else:
  print('No Skill or Experience')
# Out:
# No Skill or Experience

# %%
job_skill = 'SQL'
applicant_skill = 'Python'
years_experience = 3


if job_skill == applicant_skill:
  print('Skills Match')
elif years_experience >= 5:
  print('Enough Experience; No SQL')
elif applicant_skill == 'Python':
  print('This applicant should know SQL')
else:
  print('No Skill or Experience')
# Out:
# This applicant should know SQL

# %%
#In a case where you aren't sure what to put in there but you know that you need to have something there later you can use pass.

if job_skill == applicant_skill:
  pass
