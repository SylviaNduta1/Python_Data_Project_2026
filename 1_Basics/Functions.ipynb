# %% [markdown]
# ![Screenshot 2026-02-08 at 22.05.35.png](data:image/png;base64,...)

# %%
data_salaries = [95000, 100000, 85000, 97000, 140000]

# %%
min(data_salaries)
# Out:
# 85000

# %%
max(data_salaries)
# Out:
# 140000

# %%
sum(data_salaries)
# Out:
# 517000

# %%
sorted(data_salaries)
# Out:
# [85000, 95000, 97000, 100000, 140000]

# %% [markdown]
# **User-Defined Functions**

# %%
base_salary = 100000
bonus_rate = 0.1

# Calculate total_salary of base_salary * (1 + bonus_rate)

def calculate_salary():
  base_salary = 100000
  bonus_rate = 0.1

  total_salary = base_salary * (1 + bonus_rate)

  return total_salary

# %%
calculate_salary()
# Out:
# 110000.00000000001

# %%
base_salary = 100000
bonus_rate = 0.1

# Calculate total_salary of base_salary * (1 + bonus_rate)

def calculate_salary(base_salary, bonus_rate):

  total_salary = base_salary * (1 + bonus_rate)

  return total_salary

# %%
calculate_salary(base_salary, bonus_rate)
# Out:
# 110000.00000000001

# %% [markdown]
# ***Here is another way to execute the code above: ***

# %%
# Calculate total_salary of base_salary * (1 + bonus_rate)

def calculate_salary(base_salary, bonus_rate):

  total_salary = base_salary * (1 + bonus_rate)

  return total_salary

# %%
base_salary = 100000
bonus_rate = 0.1

calculate_salary(base_salary, bonus_rate)
# Out:
# 110000.00000000001

# %%
def calculate_salary(base_salary, bonus_rate=.1):

  total_salary = base_salary * (1 + bonus_rate)

  return total_salary

# %%
base_salary = 100000
bonus_rate = 0.1

calculate_salary(base_salary)
# Out:
# 110000.00000000001

# %% [markdown]
# ![Screenshot 2026-02-10 at 14.10.29.png](data:image/png;base64,...)

# %%
def my_experience():
    pass

# Calling the function does nothing but is syntactically valid
my_experience()
