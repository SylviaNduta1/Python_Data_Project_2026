# %% [markdown]
# ![Screenshot 2026-02-07 at 18.35.08.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-02-07 at 18.35.59.png](data:image/png;base64,...)

# %%
job_work_from_home = True
job_health_insurance = True

job_work_from_home and job_health_insurance
# Out:
# True

# %%
job_work_from_home = True
job_health_insurance = False

job_work_from_home and job_health_insurance
# Out:
# False

# %%
job_work_from_home = True
job_health_insurance = False
job_no_degree_mention = True

job_work_from_home and job_health_insurance and job_no_degree_mention
# Out:
# False

# %%
job_work_from_home = True
job_health_insurance = True
job_no_degree_mention = True

job_work_from_home and job_health_insurance and job_no_degree_mention
# Out:
# True

# %%
job_work_from_home = True
job_health_insurance = False
#job_no_degree_mention = True

job_work_from_home or job_health_insurance
# Out:
# True

# %%
job_work_from_home = False
job_health_insurance = False
#job_no_degree_mention = True

job_work_from_home or job_health_insurance
# Out:
# False

# %%
job_work_from_home = False
job_health_insurance = False
job_no_degree_mention = True

job_work_from_home or job_health_insurance or job_no_degree_mention
# Out:
# True

# %%
not True
# Out:
# False

# %%
job_work_from_home = False
job_health_insurance = False
job_no_degree_mention = True

job_work_from_home or job_health_insurance or not job_no_degree_mention
# Out:
# False

# %% [markdown]
# ![Screenshot 2026-02-08 at 19.51.24.png](data:image/png;base64,...)

# %%
#Check whether Data is inside of the Data nerd

"Data" in "Data Nerd"
# Out:
# True

# %%
#Please note that they are case sensitive. Therefore if I write a small d instead of capital D, it will return false

"data" in "Data Nerd"
# Out:
# False

# %%
job_skills = ['python', 'r', 'sql']

# %%
'python' in job_skills
# Out:
# True

# %%
'python' not in job_skills
# Out:
# False

# %% [markdown]
# ![Screenshot 2026-02-08 at 19.57.36.png](data:image/png;base64,...)

# %%
salary_kelly = 100_000
salary_luke = 100_000

salary_kelly is salary_luke #is is verifying if they are using the same memory location
# Out:
# False

# %%
core_skills = ['python', 'r', 'sql']
luke_skills = core_skills

# %%
luke_skills is core_skills
# Out:
# True

# %% [markdown]
# ![Screenshot 2026-02-08 at 20.01.45.png](data:image/png;base64,...)

# %%
bin(42)
# Out:
# '0b101010'
