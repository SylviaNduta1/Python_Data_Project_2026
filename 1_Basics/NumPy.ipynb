# %% [markdown]
# ![Screenshot 2026-02-10 at 21.10.18.png](data:image/png;base64,...)

# %%
#create a list of 1,000,000 salaries ranging from 50,000 to 150,000

import random

salary_list = [random.randint(50000, 100000) for _ in range (1_000_000)]

# %%
import statistics

# %%
# %%timeit

statistics.mean(salary_list)
# Out:
# 161 ms ± 13.6 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
import numpy as np

# %%
# %%timeit

np.mean(salary_list)
# Out:
# 41.7 ms ± 1.23 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
#np.array() is a function

my_array = np.array([1, 2, 3, 4])

# %%
my_array.mean()
# Out:
# np.float64(2.5)

# %%
#Job titles
job_titles = np.array(['Data Analyst', 'Data Scientist', 'Data Engineer', 'Machine Learning Engineer', 'AI Engineer'])

#Base salaries
base_salaries = np.array([60000, 80000, 75000, 90000])

#Bonus rates
bonus_rates = np.array([.05, .1, .08, .12])

# %%
total_salaries = base_salaries * (1 + bonus_rates)

total_salaries
# Out:
# array([ 63000.,  88000.,  81000., 100800.])

# %%
np.mean(total_salaries)
# Out:
# np.float64(83200.0)

# %% [markdown]
# ![Screenshot 2026-02-10 at 21.29.33.png](data:image/png;base64,...)
#
# ***NaN stands for Not A Number***

# %%
#Job titles
job_titles = np.array(['Data Analyst', 'Data Scientist', 'Data Engineer', 'Machine Learning Engineer', 'AI Engineer'])

#Base salaries
base_salaries = np.array([60000, 80000, 75000, 90000, np.nan])

#Bonus rates
bonus_rates = np.array([.05, .1, .08, .12, np.nan])

# %%
total_salaries = base_salaries * (1 + bonus_rates)

total_salaries
# Out:
# array([ 63000.,  88000.,  81000., 100800.,     nan])

# %%
np.nanmean(total_salaries)
# Out:
# np.float64(83200.0)
