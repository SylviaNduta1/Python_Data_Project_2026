# %%
variable_name = value

# %%
salary = 100000

# %%
salary
# Out:
# 100000

# %% [markdown]
# Calculate The Following
#
# Total Salary = (Base Salary) * (1 + Bonus Rate)

# %%
base_salary = 100000
bonus_rate = .10

# %%
total_salary = (base_salary) * (1 + bonus_rate)

# %%
total_salary
# Out:
# 110000.00000000001
