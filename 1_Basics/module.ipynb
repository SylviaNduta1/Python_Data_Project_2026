# %%
# %%writefile my_module.py

skill_list = ['Python', 'SQL', 'Excel']
# Out:
# Overwriting my_module.py

# %%
import my_module

my_module.skill_list
# Out:
# ['Python', 'SQL', 'Excel']

# %%
# %%writefile my_module2.py

skill_list = ['Python', 'SQL', 'Excel']

def skill(skill_name):
    return f"{skill_name} is my favorite skill!"
# Out:
# Overwriting my_module2.py

# %%
import my_module2

# Call the functions from the module
print(my_module2.skill('Python'))
# Out:
# Python is my favorite skill!

# %%
import job_analyzer

job_analyzer.calculate_salary(100000)
# Out:
# 110000.00000000001

# %%
#Another way to do the above

from job_analyzer import calculate_salary

calculate_salary(100000)
# Out:
# 110000.00000000001

# %%
#If you have two functions and wish to import them both

from job_analyzer import calculate_salary, calculate_bonus

calculate_salary(100000)

calculate_bonus(110000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-946920590.py in <cell line: 0>()
#       5 calculate_salary(100000)
#       6
# ----> 7 calculate_bonus(110000)
#
# NameError: name 'calculate_bonus' is not defined

# %% [markdown]
# **Python Standard Library**
#
# ***Statistics Module***

# %%
salary_list = [98000, 101000, 102000, 99000, 97000]

# %%
import statistics

statistics.mean(salary_list)
# Out:
# 99400

# %%
from statistics import mean, mode, median

mean(salary_list)
# Out:
# 99400

# %%
mode(salary_list)
# Out:
# 98000

# %%
median(salary_list)
# Out:
# 99000
